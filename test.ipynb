# %%
import random
import pandas as pd
from ecommerce.tables import Product, User


df = pd.read_csv("ecommerce/datas/products/Air Conditioners.csv")

df = df.rename(
    columns={
        "name": "name",
        "main_category": "category",
        "image": "image_url",
        "link": "description",
        "ratings": "rating",
        "no_of_ratings": "stock",
        "discount_price": "discount",
        "actual_price": "price",
    }
)

user_ids = User.select(User.id).run_sync()
random_user_id = random.choice(user_ids)

# for _, row in df.iterrows():
#     product = Product(
#         name=row["name"],
#         category=row["category"],
#         description=row["description"],
#         image_url=row["image_url"],
#         rating=row["rating"],
#         stock=row["stock"],
#         discount=row["discount"],
#         price=row["price"],
#         user_id=random_user_id,
#     )
#     product.save().run(DB)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[22], line 21
#       8 df = df.rename(
#       9     columns={
#      10         "name": "name",
#    (...)
#      18     }
#      19 )
# ---> 21 user_ids = User.select(User.id).run_sync()
#      22 random_user_id = random.choice(user_ids)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:226, in Query.run_sync(self, node, timed, in_pool)
#     225 if not timed:
# --> 226     return run_sync(coroutine)
#     227 with Timer():
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/utils/sync.py:24, in run_sync(coroutine)
#      23 future = executor.submit(asyncio.run, coroutine)
# ---> 24 return future.result()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File /usr/lib/python3.10/asyncio/runners.py:44, in run(main, debug)
#      43         loop.set_debug(debug)
# ---> 44     return loop.run_until_complete(main)
#      45 finally:
#
# File /usr/lib/python3.10/asyncio/base_events.py:649, in BaseEventLoop.run_until_complete(self, future)
#     647     raise RuntimeError('Event loop stopped before Future completed.')
# --> 649 return future.result()
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/methods/select.py:832, in Select.run(self, node, in_pool, use_callbacks, **kwargs)
#     825 async def run(
#     826     self,
#     827     node: t.Optional[str] = None,
#    (...)
#     830     **kwargs,
#     831 ) -> t.List[t.Dict[str, t.Any]]:
# --> 832     results = await super().run(node=node, in_pool=in_pool)
#     833     if use_callbacks:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:202, in Query.run(self, node, in_pool)
#     199 async def run(
#     200     self, node: t.Optional[str] = None, in_pool: bool = True
#     201 ) -> QueryResponseType:
# --> 202     return await self._run(node=node, in_pool=in_pool)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:167, in Query._run(self, node, in_pool)
#     165 self._validate()
# --> 167 engine = self.table._meta.db
#     169 if not engine:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/table.py:135, in TableMeta.db(self)
#     134 if not self._db:
# --> 135     db = engine_finder()
#     136     if not db:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/engine/finder.py:19, in engine_finder(module_name)
#      17 from piccolo.conf.apps import Finder
# ---> 19 return Finder().get_engine(module_name=module_name)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:424, in Finder.get_engine(self, module_name)
#     421 def get_engine(
#     422     self, module_name: t.Optional[str] = None
#     423 ) -> t.Optional[Engine]:
# --> 424     piccolo_conf = self.get_piccolo_conf_module(module_name=module_name)
#     425     engine: t.Optional[Engine] = getattr(piccolo_conf, ENGINE_VAR, None)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:410, in Finder.get_piccolo_conf_module(self, module_name)
#     409     else:
# --> 410         raise exc from exc
#     411 else:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:387, in Finder.get_piccolo_conf_module(self, module_name)
#     386 try:
# --> 387     module = t.cast(PiccoloConfModule, import_module(module_name))
#     388 except ModuleNotFoundError as exc:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'piccolo_conf'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[22], line 21
#       8 df = df.rename(
#       9     columns={
#      10         "name": "name",
#    (...)
#      18     }
#      19 )
# ---> 21 user_ids = User.select(User.id).run_sync()
#      22 random_user_id = random.choice(user_ids)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:226, in Query.run_sync(self, node, timed, in_pool)
#     225 if not timed:
# --> 226     return run_sync(coroutine)
#     227 with Timer():
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/utils/sync.py:24, in run_sync(coroutine)
#      23 future = executor.submit(asyncio.run, coroutine)
# ---> 24 return future.result()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File /usr/lib/python3.10/asyncio/runners.py:44, in run(main, debug)
#      43         loop.set_debug(debug)
# ---> 44     return loop.run_until_complete(main)
#      45 finally:
#
# File /usr/lib/python3.10/asyncio/base_events.py:649, in BaseEventLoop.run_until_complete(self, future)
#     647     raise RuntimeError('Event loop stopped before Future completed.')
# --> 649 return future.result()
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/methods/select.py:832, in Select.run(self, node, in_pool, use_callbacks, **kwargs)
#     825 async def run(
#     826     self,
#     827     node: t.Optional[str] = None,
#    (...)
#     830     **kwargs,
#     831 ) -> t.List[t.Dict[str, t.Any]]:
# --> 832     results = await super().run(node=node, in_pool=in_pool)
#     833     if use_callbacks:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:202, in Query.run(self, node, in_pool)
#     199 async def run(
#     200     self, node: t.Optional[str] = None, in_pool: bool = True
#     201 ) -> QueryResponseType:
# --> 202     return await self._run(node=node, in_pool=in_pool)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:167, in Query._run(self, node, in_pool)
#     165 self._validate()
# --> 167 engine = self.table._meta.db
#     169 if not engine:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/table.py:135, in TableMeta.db(self)
#     134 if not self._db:
# --> 135     db = engine_finder()
#     136     if not db:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/engine/finder.py:19, in engine_finder(module_name)
#      17 from piccolo.conf.apps import Finder
# ---> 19 return Finder().get_engine(module_name=module_name)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:424, in Finder.get_engine(self, module_name)
#     421 def get_engine(
#     422     self, module_name: t.Optional[str] = None
#     423 ) -> t.Optional[Engine]:
# --> 424     piccolo_conf = self.get_piccolo_conf_module(module_name=module_name)
#     425     engine: t.Optional[Engine] = getattr(piccolo_conf, ENGINE_VAR, None)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:410, in Finder.get_piccolo_conf_module(self, module_name)
#     409     else:
# --> 410         raise exc from exc
#     411 else:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:387, in Finder.get_piccolo_conf_module(self, module_name)
#     386 try:
# --> 387     module = t.cast(PiccoloConfModule, import_module(module_name))
#     388 except ModuleNotFoundError as exc:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'piccolo_conf'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 21
#       6 df = pd.read_csv("ecommerce/datas/products/Air Conditioners.csv")
#       8 df = df.rename(
#       9     columns={
#      10         "name": "name",
#    (...)
#      18     }
#      19 )
# ---> 21 user_ids = User.select(User.id).run_sync()
#      22 random_user_id = random.choice(user_ids)
#      24 # for _, row in df.iterrows():
#      25 #     product = Product(
#      26 #         name=row["name"],
#    (...)
#      35 #     )
#      36 #     product.save().run(DB)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:226, in Query.run_sync(self, node, timed, in_pool)
#     223 coroutine = self.run(node=node, in_pool=in_pool)
#     225 if not timed:
# --> 226     return run_sync(coroutine)
#     227 with Timer():
#     228     return run_sync(coroutine)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/utils/sync.py:24, in run_sync(coroutine)
#      22 with ThreadPoolExecutor(max_workers=1) as executor:
#      23     future = executor.submit(asyncio.run, coroutine)
# ---> 24     return future.result()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /usr/lib/python3.10/asyncio/runners.py:44, in run(main, debug)
#      42     if debug is not None:
#      43         loop.set_debug(debug)
# ---> 44     return loop.run_until_complete(main)
#      45 finally:
#      46     try:
#
# File /usr/lib/python3.10/asyncio/base_events.py:649, in BaseEventLoop.run_until_complete(self, future)
#     646 if not future.done():
#     647     raise RuntimeError('Event loop stopped before Future completed.')
# --> 649 return future.result()
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/methods/select.py:832, in Select.run(self, node, in_pool, use_callbacks, **kwargs)
#     825 async def run(
#     826     self,
#     827     node: t.Optional[str] = None,
#    (...)
#     830     **kwargs,
#     831 ) -> t.List[t.Dict[str, t.Any]]:
# --> 832     results = await super().run(node=node, in_pool=in_pool)
#     833     if use_callbacks:
#     834         return await self.callback_delegate.invoke(
#     835             results, kind=CallbackType.success
#     836         )
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:202, in Query.run(self, node, in_pool)
#     199 async def run(
#     200     self, node: t.Optional[str] = None, in_pool: bool = True
#     201 ) -> QueryResponseType:
# --> 202     return await self._run(node=node, in_pool=in_pool)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/query/base.py:167, in Query._run(self, node, in_pool)
#     153 """
#     154 Run the query on the database.
#     155
#    (...)
#     163
#     164 """  # noqa: E501
#     165 self._validate()
# --> 167 engine = self.table._meta.db
#     169 if not engine:
#     170     raise ValueError(
#     171         f"Table {self.table._meta.tablename} has no db defined in "
#     172         "_meta"
#     173     )
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/table.py:135, in TableMeta.db(self)
#     132 @property
#     133 def db(self) -> Engine:
#     134     if not self._db:
# --> 135         db = engine_finder()
#     136         if not db:
#     137             raise Exception("Unable to find the engine")
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/engine/finder.py:19, in engine_finder(module_name)
#       9 """
#      10 An example module name is `my_piccolo_conf`.
#      11
#    (...)
#      15 The module must be available on the path, so Python can import it.
#      16 """
#      17 from piccolo.conf.apps import Finder
# ---> 19 return Finder().get_engine(module_name=module_name)
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:424, in Finder.get_engine(self, module_name)
#     421 def get_engine(
#     422     self, module_name: t.Optional[str] = None
#     423 ) -> t.Optional[Engine]:
# --> 424     piccolo_conf = self.get_piccolo_conf_module(module_name=module_name)
#     425     engine: t.Optional[Engine] = getattr(piccolo_conf, ENGINE_VAR, None)
#     427     if not engine:
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:410, in Finder.get_piccolo_conf_module(self, module_name)
#     405         raise ModuleNotFoundError(
#     406             "SQLite driver not found. "
#     407             "Try running `pip install 'piccolo[sqlite]'`"
#     408         ) from exc
#     409     else:
# --> 410         raise exc from exc
#     411 else:
#     412     return module
#
# File ~/.cache/pypoetry/virtualenvs/e-commerce-fastapi-mNKRKWrz-py3.10/lib/python3.10/site-packages/piccolo/conf/apps.py:387, in Finder.get_piccolo_conf_module(self, module_name)
#     384     module_name = DEFAULT_MODULE_NAME
#     386 try:
# --> 387     module = t.cast(PiccoloConfModule, import_module(module_name))
#     388 except ModuleNotFoundError as exc:
#     389     if self.diagnose:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'piccolo_conf'
